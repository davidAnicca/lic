# %%
from model.GA.GA import GeneticSAW

# %%
from model.GA.GA import GeneticSAW
from model.GA.matri import create_lattice_diagram, create_visual
from IPython.display import display, Image

def show(visual_code: list):
    img = create_lattice_diagram(visual_code)
    display(img)

# %%
min_score = 0
best_k = 1
raw = 'PHHHHHHHHHHHHHHP'

best, score = GeneticSAW.run(
    raw=raw,
    population_size=1000,
    generations=50,
    mutation_rate=0.2,
    tournament_k=10,
    elitism=50,
    rng_seed=42
)

show(create_visual(raw, best.ruld))
print(best.ruld)
print(len(best.xs))

print("Best score:", score)
# Out:
# not len!
# not len!
# not len!
# rotated!
# RULD: RRRDLLDRRRDDRDRD
# not len!
# not len!
# not len!
# not len!
# not len!
# rotated!
# RULD: RULURRRRDLLDDLDL
# not len!
# not len!
# not len!
# fallbacked
# not len!
# fallbacked
# not len!
# not len!
# rotated!
# RULD: RDRDRDLDRRUUUUUR
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# rotated!
# RULD: RRUURDDRRDRDDRRD
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# rotated!
# RULD: RDLDLDLDDRDLLDLL
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# fallbacked
# not len!
# not len!
# rotated!
# RULD: RURDRDLLLDRRRDLD
# not len!
# not len!
# not len!
# not len!
# rotated!
# RULD: RRDLDLULLDRDLDLL
# not len!
# not len!
# not len!
# rotated!
# RULD: RRRRURRULLLDLLUU
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# not len!
# ...

# %%
ruld = 'RRULUL'
raw = 'PHHHHP'
show(create_visual(raw, best.ruld))
