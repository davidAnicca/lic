# %%
from model.GA.GA import GeneticSAW

# %%
from model.GA.GA import GeneticSAW
from model.GA.matri import create_lattice_diagram
from IPython.display import display, Image

def show(visual_code: list):
    img = create_lattice_diagram(visual_code)
    display(Image(img))

# %%
from model.GA.utils import create_visual

min_score = 0
best_k = 1
raw = 'PHHHHHHHHHHHHHHP'

best, score = GeneticSAW.run(
    raw=raw,
    population_size=10,
    generations=100,
    mutation_rate=0.2,
    tournament_k=3,
    elitism=500,
    rng_seed=40
)

show(create_visual(raw, best.ruld))
print(best.ruld)
print(len(best.xs))

print("Best score:", score)
# Out:
# RUUURDRUUULDLUUL
# 17
# Best score: -6
